# %%
import numpy as np
import matplotlib.pyplot as plt

from neural_nets.NonLinearNet import NonLinearNet

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# %load_ext autoreload
# %autoreload 2

# %%
import math
data_size = 50000
X = np.random.ranf((data_size, 2)) * 2 - 1
y = np.zeros((data_size, 1))
for i in xrange(data_size):
    #y[i] = 2 * X[i, 0] - 1 * X[i, 1]
    y[i] = 0.5 * math.pi * (X[i, 0] ** 2) * math.sin(2 * math.pi * X[i, 1])
# split to train and validation set
X_train = X[:(int)(0.8 * X.shape[0])]
X_val  = X[(int)(0.8 * X.shape[0]):]
y_train = y[:(int)(0.8 * y.shape[0])]
y_val = y[(int)(0.8 * y.shape[0]):]

net = NonLinearNet(2, 120, 1, std=1e-2)
net.forward(X)
loss_history = net.train(X, y, X_val, y_val,
            learning_rate=1e-1, reg=0.001,
            num_iters=1000, verbose=False)

# plot the loss history
plt.plot(loss_history)
plt.xlabel('iteration')
plt.ylabel('training loss history')
plt.show()
# Out:
# X_val :
# [[-0.18841947 -0.24156428]
#  [ 0.20319464 -0.90384528]
#  [ 0.48864622 -0.04137884]
#  [ 0.65365912 -0.26319618]
#  [ 0.0022917  -0.57498702]
#  [ 0.20862165  0.78370877]
#  [-0.28665398  0.29109489]
#  [ 0.81471567  0.1337373 ]
#  [ 0.39928411  0.5143915 ]
#  [-0.84835014  0.29893288]]
# y expected:
# [[ -5.56879343e-02]
#  [  3.68422094e-02]
#  [ -9.64191595e-02]
#  [ -6.68848845e-01]
#  [  3.74467650e-06]
#  [ -6.68380851e-02]
#  [  1.24794280e-01]
#  [  7.76596614e-01]
#  [ -2.26140293e-02]
#  [  1.07748647e+00]]
# y get:
# [[-0.01441155]
#  [-0.01133032]
#  [-0.01553728]
#  [-0.0145134 ]
#  [-0.01285871]
#  [-0.01942724]
#  [-0.01694279]
#  [-0.01645715]
#  [-0.01818184]
#  [-0.01684304]]
